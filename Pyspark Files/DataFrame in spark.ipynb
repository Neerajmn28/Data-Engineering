# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
.appName('DataFrame Basics') \
.getOrCreate()
# Out:
# 25/07/08 10:34:06 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
data = [
    (0,'customer_0','Bangalore','Karnataka','India','2023-11-11',True),
    (1,'customer_1','Delhi','New Delhi','India','2023-08-26',True),
]

columns = ['customer_id','name','city','state','country','registration_date','is_active']

# %%
df = spark.createDataFrame(data,columns)

# %%
df.show()
# Out:
# +-----------+----------+---------+---------+-------+-----------------+---------+
# |customer_id|      name|     city|    state|country|registration_date|is_active|
# +-----------+----------+---------+---------+-------+-----------------+---------+
# |          0|customer_0|Bangalore|Karnataka|  India|       2023-11-11|     true|
# |          1|customer_1|    Delhi|New Delhi|  India|       2023-08-26|     true|
# +-----------+----------+---------+---------+-------+-----------------+---------+

# %%
df.select('name').show()
# Out:
# +----------+
# |      name|
# +----------+
# |customer_0|
# |customer_1|
# +----------+

# %%
spark.stop()
